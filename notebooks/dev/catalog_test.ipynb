# %%
import intake
import easygems.healpix as egh

import warnings
warnings.filterwarnings("ignore", message=".*The return type of `Dataset.dims` will be changed.*", category=FutureWarning)

url = 'https://raw.githubusercontent.com/digital-earths-UK-hackathon/catalog/refs/heads/main/catalog.yaml'
cat = intake.open_catalog(url)

print([k for k in cat.keys()])

# %%
ds = cat['um_glm_n2560_CoMA9'](zoom=10, time='PT1H').to_dask()

# %%
ds

# %%
egh.healpix_show(ds.ts.isel(time=1))

# %%
[key for key in cat if key.startswith('um_')]
# Out:
# ['um_glm_n2560_RAL3p3_tuned']

# %%
cat['um_glm_n2560_RAL3p3_tuned']
# Out:
# um_glm_n2560_RAL3p3_tuned:
#   args:
#     chunks: null
#     consolidated: true
#     urlpath:
#     - http://hackathon-o.s3.jc.rl.ac.uk/sim-data/dev/v6.7.cf_compliance/glm.n2560_RAL3p3.tuned/um.PT1H.hp_z10.zarr
#   description: ''
#   driver: intake_xarray.xzarr.ZarrSource
#   metadata:
#     catalog_dir: https://raw.githubusercontent.com/digital-earths-UK-hackathon/catalog/refs/heads/main
#     configuration: RAL3p3
#     creator_email: richard.w.jones@metoffice.gov.uk, claudio.sanchez@metoffice.gov.uk,
#       huw.lewis@metoffice.gov.uk, calum.scullion@metoffice.gov.uk, dasha.shchepanovska@metoffice.gov.uk,
#       mark.muetzelfeldt@reading.ac.uk
#     creator_name: Richard W. Jones, Claudio Sanchez, Huw Lewis, Calum Scullion, Dasha
#       Shchepanovska, Mark Muetzelfeldt
#     experiment_id: hackathon
#     experiment_index: 2
#     grid_mapping: healpix
#     history: Calum Scullion ran this simulation on Atos (ECMWF), Mark Muetzelfeldt
#       converted from UM lat/lon output to healpix (JASMIN)
#     institution: Met Office
#     license: Crown Copyright, 2025, Met Office. For Educational Use and Non-Commercial
#       Research Use only.
#     project: global_hackathon
#     references: https://doi.org/10.5194/gmd-2024-201
#     region: global
#     resolution: 5km
#     simulation_id: 5km-RAL3
#     source_id: UM-5km-RAL3-global
#     summary: "Atmosphere-only simulation at 5 km resolution. Run for 1 year and 2\
#       \ months starting in 2020.\n\n**Simulation**:\n  * Source code: Regional Nesting\
#       \ Suite (RNS)\n  * Horizontal grid: 5km resolution global lat-lon grid\n  *\
#       \ Vertical grid: L85_80km - 85 levels, model top at 80km\n  * Initial conditions:\
#       \ From operational model for date 2020-01-20T00:00:00Z"
#     time_end: 2021-03-01T00:00
#     time_start: 2020-01-20 00:00:00
#     title: RAL3.3 5 km simulation

# %%
ds = cat['um_glm_n2560_RAL3p3_tuned'](time='PT3H', zoom=10) .to_dask()
ds
# Out:
# <xarray.Dataset> Size: 49TB
# Dimensions:        (time: 3249, pressure: 25, healpix_index: 12582912)
# Coordinates:
#   * time           (time) datetime64[ns] 26kB 2020-01-20 ... 2021-03-01
#   * pressure       (pressure) int64 200B 1 5 10 20 30 ... 900 925 950 975 1000
#   * healpix_index  (healpix_index) int64 101MB 0 1 2 ... 12582910 12582911
#     crs            int32 4B ...
# Data variables: (12/14)
#     cli            (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     clw            (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     hur            (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     hus            (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     orog           (healpix_index) float64 101MB dask.array<chunksize=(98304,), meta=np.ndarray>
#     qg             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     ...             ...
#     sftlf          (healpix_index) float64 101MB dask.array<chunksize=(98304,), meta=np.ndarray>
#     ta             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     ua             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     va             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     wa             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     zg             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
# Attributes:
#     regional_bounds:                  {'lower_left_lat': -90, 'lower_left_lon...
#     latitiude_convention:             [-90, 90]
#     longitude_convention:             [0, 360]
#     regional:                         False
#     simulation:                       glm.n2560_RAL3p3.tuned
#     simulation_description:           The MetUM uses a regular lat-lon grid, ...
#     Met Office DYAMOND3 simulations:  A group of experiments have been conduc...
#     Conventions:                      CF-1.13

# %%
ds
# Out:
# <xarray.Dataset> Size: 49TB
# Dimensions:        (time: 3249, pressure: 25, healpix_index: 12582912)
# Coordinates:
#   * time           (time) datetime64[ns] 26kB 2020-01-20 ... 2021-03-01
#   * pressure       (pressure) int64 200B 1 5 10 20 30 ... 900 925 950 975 1000
#   * healpix_index  (healpix_index) int64 101MB 0 1 2 ... 12582910 12582911
#     crs            int32 4B ...
# Data variables: (12/14)
#     cli            (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     clw            (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     hur            (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     hus            (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     orog           (healpix_index) float64 101MB dask.array<chunksize=(98304,), meta=np.ndarray>
#     qg             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     ...             ...
#     sftlf          (healpix_index) float64 101MB dask.array<chunksize=(98304,), meta=np.ndarray>
#     ta             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     ua             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     va             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     wa             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
#     zg             (time, pressure, healpix_index) float32 4TB dask.array<chunksize=(1, 5, 1048576), meta=np.ndarray>
# Attributes:
#     regional_bounds:                  {'lower_left_lat': -90, 'lower_left_lon...
#     latitiude_convention:             [-90, 90]
#     longitude_convention:             [0, 360]
#     regional:                         False
#     simulation:                       glm.n2560_RAL3p3.tuned
#     simulation_description:           The MetUM uses a regular lat-lon grid, ...
#     Met Office DYAMOND3 simulations:  A group of experiments have been conduc...
#     Conventions:                      CF-1.13
